# %%
#Import Libraries

# %matplotlib inline
import sklearn
import sklearn.mixture
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import seaborn as sns
import umap
from sklearn.mixture import GaussianMixture
import decimal
sns.set_palette(sns.color_palette("hls", 20))

# %%
#Read in Data

data = pd.read_csv('Updated_BM_AM_180808_RegVirtStackSlices-Table_2.csv')
new_data = data[["Islet1","Pax6","CABP5","SCGN","CAVIII","Rec","Calb","Parv"]]
array_data = new_data.iloc[0:10672, 0:8].values
print(array_data)
# Out:
# [[ 1219.007   449.386  2832.377 ... 13829.995  1027.346   578.774]
#  [ 1588.703   401.111  2343.677 ...  3100.799   639.677   549.374]
#  [ 1118.557   389.423  2209.799 ...  2365.397   651.101   368.244]
#  ...
#  [ 2531.54   1010.463  3051.905 ...  3069.165  1598.963  3133.865]
#  [ 3109.789  3357.271  2854.798 ...  1959.346  1566.262   743.254]
#  [ 5983.552  1180.479  4615.378 ... 10313.843  2348.213  3884.273]]

# %%
#Running PCA on Input Data In Order to Make it 2-Dimensional

pca = PCA(n_components=2)
principalComponents = pca.fit_transform(array_data)
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
array_principalDf = principalDf.iloc[0:10672, 0:2].values

# %%
#Plotting PCA Output

plt.scatter(array_principalDf[:,0],array_principalDf[:,1],c='black')

# %%
#Running KMeans on the raw data

kmeans = KMeans(n_clusters=8, random_state = 123)
kmeans.fit(array_data)
print(kmeans.labels_)
#Visualizing K-Means with 8 clusters using PCA

color_array = ['r', 'g', 'b', 'y', 'k', 'lime', 'm', 'aqua']
symbol_array = ['+', 'o', '*', "v","s", '.', "D", "1"]
my_dictionary = {}

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(array_principalDf[i,0],array_principalDf[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using PCA')
plt.show()
# Out:
# [6 2 2 ... 2 5 6]

# %%
#250 Iterations

tsne = TSNE(n_components = 2, n_iter = 250, perplexity = 30, random_state = 123)
tsne_run = tsne.fit_transform(array_data)
my_dictionary = {}
counter = 0

#Visualizing K-Means with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])
    counter += 1

print(counter)
plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using t-SNE')
plt.show()
# Out:
# 10672

# %%
#500 Iterations

tsne = TSNE(n_components = 2, n_iter = 500, perplexity = 30, random_state = 123)
tsne_run = tsne.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using t-SNE')
plt.show()

# %%
#1000 Iterations

tsne = TSNE(n_components = 2, n_iter = 1000, perplexity = 30, random_state = 123)
tsne_run = tsne.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using t-SNE')
plt.show()

# %%
#2000 Iterations

tsne = TSNE(n_components = 2, n_iter = 2000, perplexity = 30, random_state = 123)
tsne_run = tsne.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using t-SNE')
plt.show()

# %%
#3000 Iterations

tsne = TSNE(n_components = 2, n_iter = 3000, perplexity = 30, random_state = 123)
tsne_run = tsne.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using t-SNE')
plt.show()

# %%
#4000 Iterations

tsne = TSNE(n_components = 2, n_iter = 4000, perplexity = 30, random_state = 123)
tsne_run = tsne.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using t-SNE')
plt.show()

# %%
#5000 Iterations

tsne = TSNE(n_components = 2, n_iter = 5000, perplexity = 30, random_state = 123)
tsne_run = tsne.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using t-SNE')
plt.show()

# %%
#5 Perplexity, and 1000 Iterations

tsne = TSNE(n_components = 2, n_iter = 1000, perplexity = 5, random_state = 123)
tsne_run = tsne.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using t-SNE')
plt.show()

# %%
#30 Perplexity, and 1000 Iterations

tsne = TSNE(n_components = 2, n_iter = 1000, perplexity = 30, random_state = 123)
tsne_run = tsne.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using t-SNE')
plt.show()

# %%
#50 Perplexity, and 1000 Iterations

tsne = TSNE(n_components = 2, n_iter = 1000, perplexity = 50, random_state = 123)
tsne_run = tsne.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using t-SNE')
plt.show()

# %%
#100 Perplexity, and 1000 Iterations

tsne = TSNE(n_components = 2, n_iter = 1000, perplexity = 100, random_state = 123)
tsne_run = tsne.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using t-SNE')
plt.show()

# %%
#200 Perplexity, and 1000 Iterations

tsne = TSNE(n_components = 2, n_iter = 1000, perplexity = 200, random_state = 123)
tsne_run = tsne.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using t-SNE')
plt.show()

# %%
#Running UMAP with default of 15 neighbors

reducer = umap.UMAP(random_state = 123)
umap_run = reducer.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using UMAP

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(umap_run[i,0],umap_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using UMAP')
plt.show()

# %%
#Running UMAP with 30 neighbors

reducer = umap.UMAP(n_neighbors=30, random_state = 123)
umap_run = reducer.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using UMAP

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(umap_run[i,0],umap_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using UMAP')
plt.show()

# %%
#Running UMAP with 50 neighbors

reducer = umap.UMAP(n_neighbors=50, random_state = 123)
umap_run = reducer.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using UMAP

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(umap_run[i,0],umap_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using UMAP')
plt.show()

# %%
#Running UMAP with 100 neighbors

reducer = umap.UMAP(n_neighbors=100, random_state = 123)
umap_run = reducer.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using UMAP

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(umap_run[i,0],umap_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using UMAP')
plt.show()

# %%
#Running UMAP with 200 neighbors

reducer = umap.UMAP(n_neighbors=200, random_state = 123)
umap_run = reducer.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using UMAP

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(umap_run[i,0],umap_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using UMAP')
plt.show()

# %%
#Running UMAP with 500 neighbors

reducer = umap.UMAP(n_neighbors=500, random_state = 123)
umap_run = reducer.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using UMAP

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(umap_run[i,0],umap_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using UMAP')
plt.show()

# %%
#Running UMAP with 1000 neighbors

reducer = umap.UMAP(n_neighbors=1000, random_state = 123)
umap_run = reducer.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using UMAP

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(umap_run[i,0],umap_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using UMAP')
plt.show()

# %%
#Running UMAP with 2000 neighbors

reducer = umap.UMAP(n_neighbors=2000, random_state = 123)
umap_run = reducer.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using UMAP

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(umap_run[i,0],umap_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using UMAP')
plt.show()

# %%
#Running UMAP min_dist = 0.0

reducer = umap.UMAP(min_dist = 0.0, random_state = 123)
umap_run = reducer.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using UMAP

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(umap_run[i,0],umap_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using UMAP')
plt.show()

# %%
#Running UMAP min_dist = 0.05

reducer = umap.UMAP(min_dist = 0.05, random_state = 123)
umap_run = reducer.fit_transform(array_data)
my_dictionary = {}

#Visualizing K-Means with 8 clusters using UMAP

for i in range(0, array_data.shape[0]):
    holder = kmeans.labels_[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(umap_run[i,0],umap_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing K-Means clusters using UMAP')
plt.show()

# %%
#Running GaussianMixture

gmm = GaussianMixture(n_components=8).fit(array_data)
labels = gmm.predict(array_data)
my_dictionary = {}
tsne = TSNE(n_components = 2, n_iter = 1000, perplexity = 30, random_state = 123)
tsne_run = tsne.fit_transform(array_data)

#Visualizing GaussianMixture with 8 clusters using t-SNE

for i in range(0, array_data.shape[0]):
    holder = labels[i]
    curr_value = "c" + str(holder + 1)
    my_dictionary[curr_value] = plt.scatter(tsne_run[i,0],tsne_run[i,1],c=color_array[holder],marker=symbol_array[holder])

plt.legend([my_dictionary["c1"], my_dictionary["c2"], my_dictionary["c3"], my_dictionary["c4"], my_dictionary["c5"], my_dictionary["c6"], my_dictionary["c7"], my_dictionary["c8"]],['Cluster 1', 'Cluster 2','Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6', 'Cluster 7', 'Cluster 8'])
plt.title('Visualizing GaussianMixture with 8 clusters using t-SNE')
plt.show()
# Out:
# [5 0 7 ... 6 3 6]

# %%
#Gathering all of the data into CSV files, where each image dataset has a CSV for its k-Means labels and its GaussianMixture labels

updated_data = data[["Pic_ID"]]
from math import *

newest_data = updated_data.iloc[0:10672,].values
curr_pic = '[21_s1m1]'
curr_kmeans_array = []
curr_mixture_array = []

for i in range(0, array_data.shape[0]):
    if newest_data[i] == '21_s1m1':
        curr_kmeans_array.append(kmeans.labels_[i])
        curr_mixture_array.append(labels[i])
    elif not pd.isnull(newest_data[i]):
        kmeans_csv = pd.DataFrame(np.array(curr_kmeans_array).reshape(len(curr_kmeans_array), 1), columns = ['Kmeans labels'])
        mixture_csv = pd.DataFrame(np.array(curr_mixture_array).reshape(len(curr_mixture_array), 1), columns = ['Mixture labels'])
        kmeans_file_name = str(curr_pic) + '_kmeans_labels.csv'
        mixture_file_name = str(curr_pic) + '_mixture_labels.csv'
        kmeans_csv.to_csv(kmeans_file_name)
        mixture_csv.to_csv(mixture_file_name)
        curr_pic = newest_data[i]
        curr_kmeans_array = []
        curr_mixture_array = []
    else:
        curr_kmeans_array.append(kmeans.labels_[i])
        curr_mixture_array.append(labels[i])
# Out:
# 10672

# %%
tsne = TSNE(n_components = 2, n_iter = 500, perplexity = 30, random_state = 123)
tsne_run = tsne.fit_transform(array_data)

# %%
# first_array = []
# second_array = []
# third_array = ['current data']
# heatmap_values = []
# for i in range(10672):
#     first_array.append(array_data[i][1])
#     second_array.append(i)
# #second_array = [first_array, first_array]
# new_dataframe = pd.DataFrame(first_array, index = second_array, columns = third_array)
# heatmap = sns.heatmap(new_dataframe, annot = True)
# #plt.show()
# for txt in heatmap.texts:
#     heatmap_values.append(txt.get_text())
# #print(heatmap_values)
# max_value = max(heatmap_values)
# #print(heatmap_values)
# #print(type(max_value))
# for i in range(len(heatmap_values)):
# #     print("curr")
# #     print(heatmap_values[i])
# #     print("max")
# #     print(max_value)
#     heatmap_values[i] = int(decimal.Decimal(heatmap_values[i]))/int(decimal.Decimal(max_value))
#     if heatmap_values[i] > 1:
#         heatmap_values[i] = 1
    
# #print(heatmap_values)
# #print(len(heatmap_values))

# %%
first_array = []
second_array = []
third_array = ['current data']
heatmap_values = []
for i in range(10672):
    first_array.append(array_data[i][0])
    second_array.append(i)
new_dataframe = pd.DataFrame(first_array, index = second_array, columns = third_array)
heatmap = sns.heatmap(new_dataframe, annot = True)
for txt in heatmap.texts:
    heatmap_values.append(txt.get_text())
max_value = max(heatmap_values)
for i in range(len(heatmap_values)):
    heatmap_values[i] = int(decimal.Decimal(heatmap_values[i]))/int(decimal.Decimal(max_value))
    if heatmap_values[i] > 1:
        heatmap_values[i] = 1

# %%
for i in range(array_data.shape[0]):
    holder = heatmap_values[i]
    plt.scatter(tsne_run[i][0],tsne_run[i][1],c=str(holder))
plt.show()

# %%
first_array = []
second_array = []
third_array = ['current data']
heatmap_values = []
for i in range(10672):
    first_array.append(array_data[i][1])
    second_array.append(i)
new_dataframe = pd.DataFrame(first_array, index = second_array, columns = third_array)
heatmap = sns.heatmap(new_dataframe, annot = True)
for txt in heatmap.texts:
    heatmap_values.append(txt.get_text())
max_value = max(heatmap_values)
for i in range(len(heatmap_values)):
    heatmap_values[i] = int(decimal.Decimal(heatmap_values[i]))/int(decimal.Decimal(max_value))
    if heatmap_values[i] > 1:
        heatmap_values[i] = 1

# %%
for i in range(array_data.shape[0]):
    holder = heatmap_values[i]
    plt.scatter(tsne_run[i][0],tsne_run[i][1],c=str(holder))
plt.show()

# %%
first_array = []
second_array = []
third_array = ['current data']
heatmap_values = []
for i in range(10672):
    first_array.append(array_data[i][2])
    second_array.append(i)
new_dataframe = pd.DataFrame(first_array, index = second_array, columns = third_array)
heatmap = sns.heatmap(new_dataframe, annot = True)
for txt in heatmap.texts:
    heatmap_values.append(txt.get_text())
max_value = max(heatmap_values)
for i in range(len(heatmap_values)):
    heatmap_values[i] = int(decimal.Decimal(heatmap_values[i]))/int(decimal.Decimal(max_value))
    if heatmap_values[i] > 1:
        heatmap_values[i] = 1

# %%
for i in range(array_data.shape[0]):
    holder = heatmap_values[i]
    plt.scatter(tsne_run[i][0],tsne_run[i][1],c=str(holder))
plt.show()

# %%
first_array = []
second_array = []
third_array = ['current data']
heatmap_values = []
for i in range(10672):
    first_array.append(array_data[i][3])
    second_array.append(i)
new_dataframe = pd.DataFrame(first_array, index = second_array, columns = third_array)
heatmap = sns.heatmap(new_dataframe, annot = True)
for txt in heatmap.texts:
    heatmap_values.append(txt.get_text())
max_value = max(heatmap_values)
for i in range(len(heatmap_values)):
    heatmap_values[i] = int(decimal.Decimal(heatmap_values[i]))/int(decimal.Decimal(max_value))
    if heatmap_values[i] > 1:
        heatmap_values[i] = 1

# %%
for i in range(array_data.shape[0]):
    holder = heatmap_values[i]
    plt.scatter(tsne_run[i][0],tsne_run[i][1],c=str(holder))
plt.show()

# %%
first_array = []
second_array = []
third_array = ['current data']
heatmap_values = []
for i in range(10672):
    first_array.append(array_data[i][4])
    second_array.append(i)
new_dataframe = pd.DataFrame(first_array, index = second_array, columns = third_array)
heatmap = sns.heatmap(new_dataframe, annot = True)
for txt in heatmap.texts:
    heatmap_values.append(txt.get_text())
max_value = max(heatmap_values)
for i in range(len(heatmap_values)):
    heatmap_values[i] = int(decimal.Decimal(heatmap_values[i]))/int(decimal.Decimal(max_value))
    if heatmap_values[i] > 1:
        heatmap_values[i] = 1

# %%
for i in range(array_data.shape[0]):
    holder = heatmap_values[i]
    plt.scatter(tsne_run[i][0],tsne_run[i][1],c=str(holder))
plt.show()

# %%
first_array = []
second_array = []
third_array = ['current data']
heatmap_values = []
for i in range(10672):
    first_array.append(array_data[i][5])
    second_array.append(i)
new_dataframe = pd.DataFrame(first_array, index = second_array, columns = third_array)
heatmap = sns.heatmap(new_dataframe, annot = True)
for txt in heatmap.texts:
    heatmap_values.append(txt.get_text())
max_value = max(heatmap_values)
for i in range(len(heatmap_values)):
    heatmap_values[i] = int(decimal.Decimal(heatmap_values[i]))/int(decimal.Decimal(max_value))
    if heatmap_values[i] > 1:
        heatmap_values[i] = 1

# %%
for i in range(array_data.shape[0]):
    holder = heatmap_values[i]
    plt.scatter(tsne_run[i][0],tsne_run[i][1],c=str(holder))
plt.show()

# %%
first_array = []
second_array = []
third_array = ['current data']
heatmap_values = []
for i in range(10672):
    first_array.append(array_data[i][6])
    second_array.append(i)
new_dataframe = pd.DataFrame(first_array, index = second_array, columns = third_array)
heatmap = sns.heatmap(new_dataframe, annot = True)
for txt in heatmap.texts:
    heatmap_values.append(txt.get_text())
max_value = max(heatmap_values)
for i in range(len(heatmap_values)):
    heatmap_values[i] = int(decimal.Decimal(heatmap_values[i]))/int(decimal.Decimal(max_value))
    if heatmap_values[i] > 1:
        heatmap_values[i] = 1

# %%
for i in range(array_data.shape[0]):
    holder = heatmap_values[i]
    plt.scatter(tsne_run[i][0],tsne_run[i][1],c=str(holder))
plt.show()

# %%
first_array = []
second_array = []
third_array = ['current data']
heatmap_values = []
for i in range(10672):
    first_array.append(array_data[i][7])
    second_array.append(i)
new_dataframe = pd.DataFrame(first_array, index = second_array, columns = third_array)
heatmap = sns.heatmap(new_dataframe, annot = True)
for txt in heatmap.texts:
    heatmap_values.append(txt.get_text())
max_value = max(heatmap_values)
for i in range(len(heatmap_values)):
    heatmap_values[i] = int(decimal.Decimal(heatmap_values[i]))/int(decimal.Decimal(max_value))
    if heatmap_values[i] > 1:
        heatmap_values[i] = 1

# %%
for i in range(array_data.shape[0]):
    holder = heatmap_values[i]
    plt.scatter(tsne_run[i][0],tsne_run[i][1],c=str(holder))
plt.show()
